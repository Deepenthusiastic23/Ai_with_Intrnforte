# %% [markdown]
# # Standard Scaler(Z-score Normalization)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\ai_with_intrnforte\env1\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\ai_with_intrnforte\env1\lib\site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\ai_with_intrnforte\env1\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\ai_with_intrnforte\env1\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\ai_with_intrnforte\env1\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Python implementation using scikit-learn
from sklearn.preprocessing import StandardScaler
import numpy as np

# Sample data
data = np.array([[0,0], [0,0], [1,1], [1,1]])

# Create and apply scaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

print("Original data:\n", data)
print("Scaled data:\n", scaled_data)
print("Mean:", scaled_data.mean(axis=0))
print("Std:", scaled_data.std(axis=0))
# Out:
# Original data:
#  [[0 0]
#  [0 0]
#  [1 1]
#  [1 1]]
# Scaled data:
#  [[-1. -1.]
#  [-1. -1.]
#  [ 1.  1.]
#  [ 1.  1.]]
# Mean: [0. 0.]
# Std: [1. 1.]
